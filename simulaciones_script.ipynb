# %%
# funcion para simular el modelo a primeros vecinos
from animacion_ising import animacion_funcion

# funcion para simular el modelo de contactos aleatorios
from animacion_ising import animacion_funcion_int, animacion_funcion_array

# funcion para simular el modelo de contactos dinamicos
from animacion_ising import animacion_funcion_int_dinamico, animacion_funcion_array_dinamico

# %% [markdown]
# # Simulaciones del modelo de ISING

# %% [markdown]
# ## 1. Primeros vecinos

# %%
N = 128
T = 0.9
frames = 400
step_frame = 800
animacion_funcion(N, T, frames, step_frame)

# %% [markdown]
# ## 2. Vecinos aleatorios
# ### 2.1. $\nu$

# %%
N = 128
T = 0.9
frames = 300
step_frame = 400
nu = 5
animacion_funcion_int(N, T, nu, frames, step_frame)

# %% [markdown]
# ### 2.2. Gauss

# %%
N = 20
T = 1.5
frames = 500
step_frame = 20
mu = 5
sigma = 14
animacion_funcion_array(N, T, mu, sigma, frames, step_frame)

# %% [markdown]
# ## 3. Dinámica de vecinos
# ### 3.1. $\nu$

# %%
N = 20
T = 1.5
frames = 500
step_frame = 20
nu = 4
animacion_funcion_int_dinamico(N, T, nu, frames, step_frame)

# %% [markdown]
# ### 3.3. Gauss

# %%
N = 20
T = 1.5
frames = 500
step_frame = 20
mu = 8
sigma = 5
animacion_funcion_array_dinamico(N, T, mu, sigma, frames, step_frame)
